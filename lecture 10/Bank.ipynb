# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_datareader import DataReader

from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.stattools import adfuller, kpss

from sklearn.metrics  import mean_absolute_percentage_error,mean_squared_error, r2_score

# %%
raw = DataReader('BAC', start = '1990-01-02', end = '2019-12-31', data_source = 'yahoo')['Adj Close']
raw = pd.DataFrame(raw)
raw
# Out:
#             Adj Close
# Date
# 1990-01-02   4.750756
# 1990-01-03   4.788967
# 1990-01-04   4.687075
# 1990-01-05   4.585182
# 1990-01-08   4.610654
# ...               ...
# 2019-12-24  33.488533
# 2019-12-26  33.773781
# 2019-12-27  33.612137
# 2019-12-30  33.421967
# 2019-12-31  33.488533
#
# [7559 rows x 1 columns]

# %% [markdown]
# ### Averaging data for each month

# %%
df = raw.resample(rule = 'M').last()
df
# Out:
#             Adj Close
# Date
# 1990-01-31   4.279502
# 1990-02-28   4.570592
# 1990-03-31   3.980010
# 1990-04-30   3.902977
# 1990-05-31   4.017132
# ...               ...
# 2019-08-31  25.845184
# 2019-09-30  27.585352
# 2019-10-31  29.571272
# 2019-11-30  31.509907
# 2019-12-31  33.488533
#
# [360 rows x 1 columns]

# %%
plt.rc("figure", figsize = (16, 8))
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Before analysing dataset have to make time series stationary
